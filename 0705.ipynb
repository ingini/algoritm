# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="C:\Windows\Fonts\malgun.ttf").get_name()
rc('font', family=font_name)

# %%
import plotly.plotly as py
import cufflinks as cf
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('시구넣은거.xlsx')

# %%
df.head(1)

# %%
df.columns

# %%
df['year'] = (df['날짜']/10000).astype('int')

# %%
df['month'] = (df['year']/100).astype('int')

# %%
df.head(1)
# Out:
#        시   군구        날짜 sex    age category  qty  max_temp  max_wind  \
# 0  서울특별시  동작구  20160101   F  00~19       과자   35       5.5       2.3
#
#    min_temp  avg_temp  avg_hum  avg_wind  rain  year  month
# 0      -1.2       2.5     63.0       1.0   0.0  2016     20

# %%
sns.catplot(x='시', y= '평균기온', data=df,col='year', kind= 'bar')

# %%
sns.catplot(x='시', y= '평균습도', data=df,col='year', kind= 'bar')

# %%
sns.catplot(x='시', y= '평균풍속', data=df,col='year', kind= 'bar')

# %%
sns.catplot(x='시', y= '일강수량', data=df,col='year', kind='bar')

# %%
sns.catplot(x='군구', y= '평균기온', data=df,col='year', kind= 'bar')

# %%
sns.catplot(x='군구', y= '평균습도', data=df,col='year', kind= 'bar')

# %%
sns.catplot(x='군구', y= '평균풍속', data=df,col='year', kind= 'bar')

# %%
sns.catplot(x='군구', y= '일강수량', data=df,col='year', kind= 'bar')

# %%
df2 = pd.read_excel('시구넣은거.xlsx')

# %%
df2.head(3)
# Out:
#    Unnamed: 0 sex    age category  qty  max_temp  max_wind  min_temp  \
# 0    20160101   F  00~19       과자   35       5.5       2.3      -1.2
# 1    20160101   F  40~59    아이스크림   78       5.5       2.3      -1.2
# 2    20160101   F  60~99       과자   14       5.5       2.3      -1.2
#
#    avg_temp  avg_hum  avg_wind  rain      시   군구
# 0       2.5     63.0       1.0   0.0  서울특별시  동작구
# 1       2.5     63.0       1.0   0.0  서울특별시  동작구
# 2       2.5     63.0       1.0   0.0  서울특별시  동작구
#    Unnamed: 0 sex    age category  qty  max_temp  max_wind  min_temp  \
# 0    20160101   F  00~19       과자   35       5.5       2.3      -1.2
# 1    20160101   F  40~59    아이스크림   78       5.5       2.3      -1.2
# 2    20160101   F  60~99       과자   14       5.5       2.3      -1.2
#
#    avg_temp  avg_hum  avg_wind  rain      시   군구
# 0       2.5     63.0       1.0   0.0  서울특별시  동작구
# 1       2.5     63.0       1.0   0.0  서울특별시  동작구
# 2       2.5     63.0       1.0   0.0  서울특별시  동작구

# %%
df.corr(method='pearson')

# %%
df = df.rename(columns = {'Unnamed: 0':'날짜'})

# %%
df['year'] = (df['날짜']/10000).astype('int')

# %%
df['month'] = (df['year']/100).astype('int')

# %%
df.head(1)
# Out:
#          날짜 sex    age category  qty  max_temp  max_wind  min_temp  avg_temp  \
# 0  20160101   F  00~19       과자   35       5.5       2.3      -1.2       2.5
#
#    avg_hum  avg_wind  rain      시   군구  year  month
# 0     63.0       1.0   0.0  서울특별시  동작구  2016     20
#          날짜 sex    age category  qty  max_temp  max_wind  min_temp  avg_temp  \
# 0  20160101   F  00~19       과자   35       5.5       2.3      -1.2       2.5
#
#    avg_hum  avg_wind  rain      시   군구  year  month
# 0     63.0       1.0   0.0  서울특별시  동작구  2016     20

# %%
age = df['age'].unique()
age_point_replace = {'00~19' : 10, '20~39' : 20, '40~59' : 40, '60~99' : 60}
df['age'].apply(lambda x : age_point_replace.get(x))

# %%
df['age'] = df['age'].apply(lambda x : age_point_replace.get(x))

# %%
df.head(1)

# %%
sns.catplot(x='시',y='rain',hue='year',data=df.query('rain > 0'),kind = 'bar')

# %%
import plotly 
plotly.tools.set_credentials_file(username='DemoAccount', api_key='lr1c37zw81')

# %%
import plotly 
plotly.tools.set_config_file(world_readable=False,
                             sharing='private')

# %%
sns.catplot(x='max_temp', y= 'qty', data=df,col='category', kind= 'point')

# %%
sns.catplot(x='avg_temp', y= 'qty', data=df, col='category', kind= 'point',figsize = 6)

# %%
g = sns.catplot(x="군구", y="rain", row="year", kind="box", data=df.query("rain > 0"))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'year'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-6d1836cf3247> in <module>
# ...

# %%
sns.catplot(x="category", y="qty", hue="year", col="sex", kind="swarm", data=df)

# %%
sns.catplot(x="category", y="qty", kind="boxen",
            data=df.sort_values("month"));

# %%
sns.catplot(x="category", y="qty", hue="sex", kind="point", data=df);

# %%
sns.catplot(x="qty", y="군구", hue="year",
            kind="violin", data=df);

# %%
plt.title("Boxplot과 Strip Plot로 표현한, 요일 별 팁")
sns.boxplot(x="category", y="qty", data=df)
sns.stripplot(x="category", y="qty", data=df)
plt.show()

# %%
sns.catplot(x="category", y="qty", hue="year", row="sex", data=df,
            kind="violin")

# %%
sns.stripplot(x="category", y="qty", hue="year", row= 'sex',
              data=df, jitter=True, dodge=True)
plt.title("Strip Plot, Split=True")
plt.show()

# %%
sns.stripplot(x="category", y="qty", hue="year",
              data=df, jitter=True, dodge=True)
plt.title("Strip Plot, Split=True")
plt.show()

# %%
sns.violinplot(x="category", y="qty", hue="sex", data=df, split=True)
plt.title("Violin Plot, Split=True")
plt.show()

# %%
sns.stripplot(x="category", y="qty", hue="sex", data=df)
plt.title("category qty")
plt.legend(loc=1)
plt.show()

# %%
sns.stripplot(x="category", y="qty", hue="year", data=df)
plt.title("category qty")
plt.legend(loc=1)
plt.show()

# %%
sns.violinplot(x="category", y="age",hue= 'sex', data=df)
plt.title("category age")
plt.show()

# %%
sns.catplot(x='category', y= 'age', data=df2,col='sex', kind= 'bar')

# %%
sns.catplot(x='군구', y= 'avg_temp', data=df2,col='year', kind= 'bar')

# %%
sns.catplot(x='군구', y= 'avg_hum', data=df2,col='year', kind= 'bar')

# %%
sns.catplot(x='군구', y= 'avg_wind', data=df2,col='year', kind= 'bar')
plt.legend(loc='upper right')
plt.show()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
sns.catplot(x='군구', y= 'rain', data=df2,col='year', kind= 'bar')

# %%
sns.catplot(x='시', y= 'avg_temp', data=df2,col='year', kind= 'bar')

# %%
sns.catplot(x='age', y= 'qty', data=df2,col='year', kind= 'bar')

# %%
sns.catplot(x='category', y= 'qty', data=df2,col='군구', kind= 'bar')

# %%
sns.catplot(x='category', y= 'qty', data=df2,col='시', kind= 'bar')

# %%
sns.catplot(x='군구', y= 'qty', data=df2,col='year', kind= 'bar')
